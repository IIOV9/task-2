# %%
import json

# %%
data = open("C:/Users/الحمد لله/OneDrive/سطح المكتب/nm_cannabis_sales_2022.json")

# %%
json.load(data)
# Out:
# [{'city': 'Cloudcroft',
#   'med_sales': '420.0',
#   'rec_sales': '1345.0',
#   'total_sales': '1765.0',
#   'month': 'April'},
#  {'city': 'Las Cruces',
#   'med_sales': '1559444.96',
#   'rec_sales': '2062544.69',
#   'total_sales': '3621989.65',
#   'month': 'April'},
#  {'city': 'Santa Fe',
#   'med_sales': '1631018.25',
#   'rec_sales': '2062544.69',
#   'total_sales': '3464707.97',
#   'month': 'April'},
#  {'city': 'Deming',
#   'med_sales': '101066.09',
#   'rec_sales': '139972.86',
#   'total_sales': '241038.95',
#   'month': 'April'},
#  {'city': 'Cedar Crest',
#   'med_sales': '51934.92',
#   'rec_sales': '56301.59',
#   'total_sales': '108236.51',
#   'month': 'April'},
#  {'city': 'Roswell',
#   'med_sales': '673226.97',
#   'rec_sales': '2364.11',
#   'total_sales': '675591.08',
#   'month': 'April'},
#  {'city': 'Tularosa',
#   'med_sales': '39771.1',
#   'rec_sales': '39470.26',
#   'total_sales': '79241.36',
#   'month': 'April'},
#  {'city': 'Las Vegas',
# ...
